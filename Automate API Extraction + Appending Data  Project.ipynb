# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10820
# 1    1027     Ethereum    ETH      ethereum              8421
# 2     825  Tether USDt   USDT        tether             74786
# 3    1839          BNB    BNB           bnb              2068
# 4    5426       Solana    SOL        solana               626
# 5      52          XRP    XRP           xrp              1229
# 6    3408         USDC   USDC      usd-coin             16750
# 7    2010      Cardano    ADA       cardano              1074
# 8    5805    Avalanche   AVAX     avalanche               664
# 9      74     Dogecoin   DOGE      dogecoin               889
# 10   1958         TRON    TRX          tron               930
# 11   1975    Chainlink   LINK     chainlink              1645
# 12   6636     Polkadot    DOT  polkadot-new               684
# 13   3890      Polygon  MATIC       polygon              1279
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df = pd.json_normalize(data['data'])
    df['Timestamp'] = pd.to_datetime('now')
##    df = pd.concat([df, df2], ignore_index=True)
    
    if not os.path.isfile(r'C:\Users\taree\API Scripts\PI.csv'):
        df.to_csv(r'C:\Users\taree\API Scripts\PI.csv', header = 'coloumn_names')
    else:
         df.to_csv(r'C:\Users\taree\API Scripts\PI.csv', mode = 'a', header= False)

# %%
import os 
from time import time
from time import sleep
# If that didn't work try using the local host URL as shown in the videoleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 9
#       7     api_runner()
#       8     print('API Runner completed')
# ----> 9     sleep(60) #sleep for 1 minute
#      10 exit()
#
# KeyboardInterrupt:

# %%
df12 = pd.read_csv(r'C:\Users\taree\API Scripts\PI.csv')
df12
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             10820
# 1            1   1027     Ethereum    ETH      ethereum              8421
# 2            2    825  Tether USDt   USDT        tether             74786
# 3            3   1839          BNB    BNB           bnb              2068
# 4            4   5426       Solana    SOL        solana               626
# 5            5     52          XRP    XRP           xrp              1229
# 6            6   3408         USDC   USDC      usd-coin             16750
# 7            7   2010      Cardano    ADA       cardano              1074
# 8            8   5805    Avalanche   AVAX     avalanche               664
# 9            9     74     Dogecoin   DOGE      dogecoin               889
# 10          10   1958         TRON    TRX          tron               930
# 11          11   1975    Chainlink   LINK     chainlink              1645
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10820
# 1    1027     Ethereum    ETH      ethereum              8421
# 2     825  Tether USDt   USDT        tether             74786
# 3    1839          BNB    BNB           bnb              2068
# 4    5426       Solana    SOL        solana               626
# 5      52          XRP    XRP           xrp              1229
# 6    3408         USDC   USDC      usd-coin             16750
# 7    2010      Cardano    ADA       cardano              1074
# 8    5805    Avalanche   AVAX     avalanche               664
# 9      74     Dogecoin   DOGE      dogecoin               889
# 10   1958         TRON    TRX          tron               930
# 11   1975    Chainlink   LINK     chainlink              1645
# 12   6636     Polkadot    DOT  polkadot-new               684
# 13   3890      Polygon  MATIC       polygon              1279
# ...

# %%
# One thing I noticed was the scientific notation.I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10820
# 1    1027     Ethereum    ETH      ethereum              8421
# 2     825  Tether USDt   USDT        tether             74786
# 3    1839          BNB    BNB           bnb              2068
# 4    5426       Solana    SOL        solana               626
# 5      52          XRP    XRP           xrp              1229
# 6    3408         USDC   USDC      usd-coin             16750
# 7    2010      Cardano    ADA       cardano              1074
# 8    5805    Avalanche   AVAX     avalanche               664
# 9      74     Dogecoin   DOGE      dogecoin               889
# 10   1958         TRON    TRX          tron               930
# 11   1975    Chainlink   LINK     chainlink              1645
# 12   6636     Polkadot    DOT  polkadot-new               684
# 13   3890      Polygon  MATIC       polygon              1279
# ...

# %%
#let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.19723                       0.19630
# Ethereum                         0.60498                       2.04988
# Tether USDt                     -0.00428                       0.00079
# BNB                             -0.00874                      -1.10766
# Solana                           0.33940                       3.26249
# XRP                              0.17125                       1.20242
# USDC                            -0.00292                       0.00885
# Cardano                          0.31436                       3.54210
# Avalanche                        0.25674                       0.62520
# Dogecoin                         0.04929                       1.22105
# TRON                            -0.03034                      -0.98123
# Chainlink                        0.90435                      -0.54156
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     0.19723
#              quote.USD.percent_change_24h    0.19630
#              quote.USD.percent_change_7d     7.77814
#              quote.USD.percent_change_30d   24.72345
#              quote.USD.percent_change_60d   19.38175
#              quote.USD.percent_change_90d   38.71374
# Ethereum     quote.USD.percent_change_1h     0.60498
#              quote.USD.percent_change_24h    2.04988
#              quote.USD.percent_change_7d    13.61015
#              quote.USD.percent_change_30d   14.40848
#              quote.USD.percent_change_60d   30.74837
#              quote.USD.percent_change_90d   40.55389
# Tether USDt  quote.USD.percent_change_1h    -0.00428
#              quote.USD.percent_change_24h    0.00079
#              quote.USD.percent_change_7d    -0.01161
#              quote.USD.percent_change_30d    0.09260
#              quote.USD.percent_change_60d    0.00851
#              quote.USD.percent_change_90d   -0.04170
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                            values
# name
# Bitcoin     quote.USD.percent_change_1h   0.19723
#             quote.USD.percent_change_24h  0.19630
#             quote.USD.percent_change_7d   7.77814
#             quote.USD.percent_change_30d 24.72345
#             quote.USD.percent_change_60d 19.38175
#             quote.USD.percent_change_90d 38.71374
# Ethereum    quote.USD.percent_change_1h   0.60498
#             quote.USD.percent_change_24h  2.04988
#             quote.USD.percent_change_7d  13.61015
#             quote.USD.percent_change_30d 14.40848
#             quote.USD.percent_change_60d 30.74837
#             quote.USD.percent_change_90d 40.55389
# Tether USDt quote.USD.percent_change_1h  -0.00428
#             quote.USD.percent_change_24h  0.00079
#             quote.USD.percent_change_7d  -0.01161
#             quote.USD.percent_change_30d  0.09260
#             quote.USD.percent_change_60d  0.00851
#             quote.USD.percent_change_90d -0.04170
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. 

index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.set_index(index)
df6
# Out:
#      values
# 0   0.19723
# 1   0.19630
# 2   7.77814
# 3  24.72345
# 4  19.38175
# 5  38.71374
# 6   0.60498
# 7   2.04988
# 8  13.61015
# 9  14.40848
# 10 30.74837
# 11 40.55389
# 12 -0.00428
# 13  0.00079
# 14 -0.01161
# 15  0.09260
# 16  0.00851
# 17 -0.04170
# 18 -0.00874
# 19 -1.10766
# 20  9.28135
# 21 12.12194
# 22 35.93023
# 23 39.17272
# 24  0.33940
# 25  3.26249
# 26  5.01277
# 27 21.15919
# 28 41.16545
# 29 99.54049
# 30  0.17125
# 31  1.20242
# 32  6.37573
# 33  2.19926
# 34 -9.54017
# 35 -9.00782
# 36 -0.00292
# 37  0.00885
# 38  0.00608
# 39 -0.03663
# 40 -0.01712
# 41  0.03839
# 42  0.31436
# 43  3.54210
# 44 15.33081
# 45 24.59712
# 46  5.75004
# 47 61.59448
# 48  0.25674
# 49  0.62520
# 50  1.82723
# 51 23.50195
# 52 -5.27290
# 53 91.54364
# 54  0.04929
# 55  1.22105
# 56  4.54851
# 57  8.57981
# 58 -6.60567
# 59  8.41108
# 60 -0.03034
# 61 -0.98123
# 62  8.70257
# 63 22.72599
# 64 31.31696
# 65 33.38246
# 66  0.90435
# 67 -0.54156
# 68 -0.13461
# 69 30.58041
# ...

# %%
# Changing column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#      values
# 0   0.19723
# 1   0.19630
# 2   7.77814
# 3  24.72345
# 4  19.38175
# 5  38.71374
# 6   0.60498
# 7   2.04988
# 8  13.61015
# 9  14.40848
# 10 30.74837
# 11 40.55389
# 12 -0.00428
# 13  0.00079
# 14 -0.01161
# 15  0.09260
# 16  0.00851
# 17 -0.04170
# 18 -0.00874
# 19 -1.10766
# 20  9.28135
# 21 12.12194
# 22 35.93023
# 23 39.17272
# 24  0.33940
# 25  3.26249
# 26  5.01277
# 27 21.15919
# 28 41.16545
# 29 99.54049
# 30  0.17125
# 31  1.20242
# 32  6.37573
# 33  2.19926
# 34 -9.54017
# 35 -9.00782
# 36 -0.00292
# 37  0.00885
# 38  0.00608
# 39 -0.03663
# 40 -0.01712
# 41  0.03839
# 42  0.31436
# 43  3.54210
# 44 15.33081
# 45 24.59712
# 46  5.75004
# 47 61.59448
# 48  0.25674
# 49  0.62520
# 50  1.82723
# 51 23.50195
# 52 -5.27290
# 53 91.54364
# 54  0.04929
# 55  1.22105
# 56  4.54851
# 57  8.57981
# 58 -6.60567
# 59  8.41108
# 60 -0.03034
# 61 -0.98123
# 62  8.70257
# 63 22.72599
# 64 31.31696
# 65 33.38246
# 66  0.90435
# 67 -0.54156
# 68 -0.13461
# 69 30.58041
# ...
